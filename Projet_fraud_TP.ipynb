# %% [markdown]
# # Projet Fraude

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn import tree
from sklearn.tree import DecisionTreeRegressor

# %% [markdown]
# ### Importer les dataset

# %%
df1 = pd.read_csv('./data/Fraud_Data.csv')
df2 = pd.read_csv('./data/IpAddress_to_Country.csv')

# %%
df1
# Out:
#         user_id          signup_time        purchase_time  purchase_value  \
# 0         22058  2015-02-24 22:55:49  2015-04-18 02:47:11              34
# 1        333320  2015-06-07 20:39:50  2015-06-08 01:38:54              16
# 2          1359  2015-01-01 18:52:44  2015-01-01 18:52:45              15
# 3        150084  2015-04-28 21:13:25  2015-05-04 13:54:50              44
# 4        221365  2015-07-21 07:09:52  2015-09-09 18:40:53              39
# ...         ...                  ...                  ...             ...
# 151107   345170  2015-01-27 03:03:34  2015-03-29 00:30:47              43
# 151108   274471  2015-05-15 17:43:29  2015-05-26 12:24:39              35
# 151109   368416  2015-03-03 23:07:31  2015-05-20 07:07:47              40
# 151110   207709  2015-07-09 20:06:07  2015-09-07 09:34:46              46
# 151111   138208  2015-06-10 07:02:20  2015-07-21 02:03:53              20
#
#             device_id  source browser sex  age    ip_address  class
# 0       QVPSPJUOCKZAR     SEO  Chrome   M   39  7.327584e+08      0
# 1       EOGFQPIZPYXFZ     Ads  Chrome   F   53  3.503114e+08      0
# 2       YSSKYOSJHPPLJ     SEO   Opera   M   53  2.621474e+09      1
# 3       ATGTXKYKUDUQN     SEO  Safari   M   41  3.840542e+09      0
# 4       NAUITBZFJKHWW     Ads  Safari   M   45  4.155831e+08      0
# ...               ...     ...     ...  ..  ...           ...    ...
# 151107  XPSKTWGPWINLR     SEO  Chrome   M   28  3.451155e+09      1
# 151108  LYSFABUCPCGBA     SEO  Safari   M   32  2.439047e+09      0
# 151109  MEQHCSJUBRBFE     SEO      IE   F   26  2.748471e+09      0
# 151110  CMCXFGRHYSTVJ     SEO  Chrome   M   37  3.601175e+09      0
# 151111  ZINIADFCLHYPG  Direct      IE   M   38  4.103825e+09      0
#
# [151112 rows x 11 columns]

# %%
df2
# Out:
#         lower_bound_ip_address  upper_bound_ip_address    country
# 0                 1.677722e+07                16777471  Australia
# 1                 1.677747e+07                16777727      China
# 2                 1.677773e+07                16778239      China
# 3                 1.677824e+07                16779263  Australia
# 4                 1.677926e+07                16781311      China
# ...                        ...                     ...        ...
# 138841            3.758092e+09              3758093311  Hong Kong
# 138842            3.758093e+09              3758094335      India
# 138843            3.758095e+09              3758095871      China
# 138844            3.758096e+09              3758096127  Singapore
# 138845            3.758096e+09              3758096383  Australia
#
# [138846 rows x 3 columns]

# %% [markdown]
# ### Créer une nouvelle colonne `country` en effectuant une jointure entre les deux dataset

# %%
g = df2.groupby('country');
df1['country']=0

for(i,x) in df1.iterrows():
    if i in df1.index and x.country in g.groups.keys():
        if  g.get_group(x.country).lower_bound_ip_address.mean()<df1[i,'ip_address']<g.get_group(x.country).upper_bound_ip_address.mean():
            df1.loc[i,'country'] = g.get_group(x.country).country

# %%
countries = []
for i in range(len(df1)):
    ip_address = df1.loc[i,'ip_address']
    tmp = df2[(df2["lower_bound_ip_address"] <= ip_address) & (df2["upper_bound_ip_address"] >= ip_address)]
    
    if len(tmp) == 1:
        countries.append(tmp['country'].values[0])
    else:
        countries.append('NA')

df1['country'] = countries
df1
# Out:
#         user_id         signup_time       purchase_time  purchase_value  \
# 0         22058 2015-02-24 22:55:49 2015-04-18 02:47:11              34
# 1        333320 2015-06-07 20:39:50 2015-06-08 01:38:54              16
# 2          1359 2015-01-01 18:52:44 2015-01-01 18:52:45              15
# 3        150084 2015-04-28 21:13:25 2015-05-04 13:54:50              44
# 4        221365 2015-07-21 07:09:52 2015-09-09 18:40:53              39
# ...         ...                 ...                 ...             ...
# 151107   345170 2015-01-27 03:03:34 2015-03-29 00:30:47              43
# 151108   274471 2015-05-15 17:43:29 2015-05-26 12:24:39              35
# 151109   368416 2015-03-03 23:07:31 2015-05-20 07:07:47              40
# 151110   207709 2015-07-09 20:06:07 2015-09-07 09:34:46              46
# 151111   138208 2015-06-10 07:02:20 2015-07-21 02:03:53              20
#
#             device_id  source browser sex  age    ip_address  class  \
# 0       QVPSPJUOCKZAR     SEO  Chrome   M   39  7.327584e+08      0
# 1       EOGFQPIZPYXFZ     Ads  Chrome   F   53  3.503114e+08      0
# 2       YSSKYOSJHPPLJ     SEO   Opera   M   53  2.621474e+09      1
# 3       ATGTXKYKUDUQN     SEO  Safari   M   41  3.840542e+09      0
# 4       NAUITBZFJKHWW     Ads  Safari   M   45  4.155831e+08      0
# ...               ...     ...     ...  ..  ...           ...    ...
# 151107  XPSKTWGPWINLR     SEO  Chrome   M   28  3.451155e+09      1
# 151108  LYSFABUCPCGBA     SEO  Safari   M   32  2.439047e+09      0
# 151109  MEQHCSJUBRBFE     SEO      IE   F   26  2.748471e+09      0
# 151110  CMCXFGRHYSTVJ     SEO  Chrome   M   37  3.601175e+09      0
# 151111  ZINIADFCLHYPG  Direct      IE   M   38  4.103825e+09      0
#
#               country        time_diff
# 0               Japan 52 days 03:51:22
# 1       United States  0 days 04:59:04
# 2       United States  0 days 00:00:01
# 3                  NA  5 days 16:41:25
# 4       United States 50 days 11:31:01
# ...               ...              ...
# 151107  United States 60 days 21:27:13
# 151108    Netherlands 10 days 18:41:10
# 151109          Japan 77 days 08:00:16
# 151110  United States 59 days 13:28:39
# 151111             NA 40 days 19:01:33
#
# [151112 rows x 13 columns]

# %% [markdown]
# ### Créer une nouvelle variable `time_diff` qui sera la différence entre les variables `purchase_time` et `signup_time`

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 151112 entries, 0 to 151111
# Data columns (total 12 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   user_id         151112 non-null  int64
#  1   signup_time     151112 non-null  object
#  2   purchase_time   151112 non-null  object
#  3   purchase_value  151112 non-null  int64
#  4   device_id       151112 non-null  object
#  5   source          151112 non-null  object
#  6   browser         151112 non-null  object
#  7   sex             151112 non-null  object
#  8   age             151112 non-null  int64
#  9   ip_address      151112 non-null  float64
#  10  class           151112 non-null  int64
#  11  country         151112 non-null  object
# dtypes: float64(1), int64(4), object(7)
# memory usage: 13.8+ MB

# %% [markdown]
# convertire purchase_time et signup_time en datetime pour faire la différence entre les deux puisqu'ils sont en object et on peut pas faire la diffrence de temps entre 2 object

# %%
df1.purchase_time = pd.to_datetime(df1.purchase_time)
df1.signup_time = pd.to_datetime(df1.signup_time)
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 151112 entries, 0 to 151111
# Data columns (total 12 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   user_id         151112 non-null  int64
#  1   signup_time     151112 non-null  datetime64[ns]
#  2   purchase_time   151112 non-null  datetime64[ns]
#  3   purchase_value  151112 non-null  int64
#  4   device_id       151112 non-null  object
#  5   source          151112 non-null  object
#  6   browser         151112 non-null  object
#  7   sex             151112 non-null  object
#  8   age             151112 non-null  int64
#  9   ip_address      151112 non-null  float64
#  10  class           151112 non-null  int64
#  11  country         151112 non-null  object
# dtypes: datetime64[ns](2), float64(1), int64(4), object(5)
# memory usage: 13.8+ MB

# %%
df1['time_diff'] = df1.purchase_time - df1.signup_time
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 151112 entries, 0 to 151111
# Data columns (total 13 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   user_id         151112 non-null  int64
#  1   signup_time     151112 non-null  datetime64[ns]
#  2   purchase_time   151112 non-null  datetime64[ns]
#  3   purchase_value  151112 non-null  int64
#  4   device_id       151112 non-null  object
#  5   source          151112 non-null  object
#  6   browser         151112 non-null  object
#  7   sex             151112 non-null  object
#  8   age             151112 non-null  int64
#  9   ip_address      151112 non-null  float64
#  10  class           151112 non-null  int64
#  11  country         151112 non-null  object
#  12  time_diff       151112 non-null  timedelta64[ns]
# dtypes: datetime64[ns](2), float64(1), int64(4), object(5), timedelta64[ns](1)
# memory usage: 15.0+ MB

# %%
df1.time_diff = df1.time_diff.apply(lambda x: x.seconds)
df1
# Out:
#         user_id         signup_time       purchase_time  purchase_value  \
# 0         22058 2015-02-24 22:55:49 2015-04-18 02:47:11              34
# 1        333320 2015-06-07 20:39:50 2015-06-08 01:38:54              16
# 2          1359 2015-01-01 18:52:44 2015-01-01 18:52:45              15
# 3        150084 2015-04-28 21:13:25 2015-05-04 13:54:50              44
# 4        221365 2015-07-21 07:09:52 2015-09-09 18:40:53              39
# ...         ...                 ...                 ...             ...
# 151107   345170 2015-01-27 03:03:34 2015-03-29 00:30:47              43
# 151108   274471 2015-05-15 17:43:29 2015-05-26 12:24:39              35
# 151109   368416 2015-03-03 23:07:31 2015-05-20 07:07:47              40
# 151110   207709 2015-07-09 20:06:07 2015-09-07 09:34:46              46
# 151111   138208 2015-06-10 07:02:20 2015-07-21 02:03:53              20
#
#             device_id  source browser sex  age    ip_address  class  \
# 0       QVPSPJUOCKZAR     SEO  Chrome   M   39  7.327584e+08      0
# 1       EOGFQPIZPYXFZ     Ads  Chrome   F   53  3.503114e+08      0
# 2       YSSKYOSJHPPLJ     SEO   Opera   M   53  2.621474e+09      1
# 3       ATGTXKYKUDUQN     SEO  Safari   M   41  3.840542e+09      0
# 4       NAUITBZFJKHWW     Ads  Safari   M   45  4.155831e+08      0
# ...               ...     ...     ...  ..  ...           ...    ...
# 151107  XPSKTWGPWINLR     SEO  Chrome   M   28  3.451155e+09      1
# 151108  LYSFABUCPCGBA     SEO  Safari   M   32  2.439047e+09      0
# 151109  MEQHCSJUBRBFE     SEO      IE   F   26  2.748471e+09      0
# 151110  CMCXFGRHYSTVJ     SEO  Chrome   M   37  3.601175e+09      0
# 151111  ZINIADFCLHYPG  Direct      IE   M   38  4.103825e+09      0
#
#               country  time_diff
# 0               Japan      13882
# 1       United States      17944
# 2       United States          1
# 3                  NA      60085
# 4       United States      41461
# ...               ...        ...
# 151107  United States      77233
# 151108    Netherlands      67270
# 151109          Japan      28816
# 151110  United States      48519
# 151111             NA      68493
#
# [151112 rows x 13 columns]

# %% [markdown]
# ### Regroupper les `user_id` par `device_id`  afin d'avoir le nombre de device par client

# %%
df1['device_num'] = 0
g = df1.groupby('device_id')
for(i,x) in df1.iterrows():
    if i in df1.index and x.device_id in g.groups.keys():
        df1.loc[i,'device_num']=g.get_group(x.device_id).user_id.count()
df1
# Out:
#         user_id         signup_time       purchase_time  purchase_value  \
# 0         22058 2015-02-24 22:55:49 2015-04-18 02:47:11              34
# 1        333320 2015-06-07 20:39:50 2015-06-08 01:38:54              16
# 2          1359 2015-01-01 18:52:44 2015-01-01 18:52:45              15
# 3        150084 2015-04-28 21:13:25 2015-05-04 13:54:50              44
# 4        221365 2015-07-21 07:09:52 2015-09-09 18:40:53              39
# ...         ...                 ...                 ...             ...
# 151107   345170 2015-01-27 03:03:34 2015-03-29 00:30:47              43
# 151108   274471 2015-05-15 17:43:29 2015-05-26 12:24:39              35
# 151109   368416 2015-03-03 23:07:31 2015-05-20 07:07:47              40
# 151110   207709 2015-07-09 20:06:07 2015-09-07 09:34:46              46
# 151111   138208 2015-06-10 07:02:20 2015-07-21 02:03:53              20
#
#             device_id  source browser sex  age    ip_address  class  \
# 0       QVPSPJUOCKZAR     SEO  Chrome   M   39  7.327584e+08      0
# 1       EOGFQPIZPYXFZ     Ads  Chrome   F   53  3.503114e+08      0
# 2       YSSKYOSJHPPLJ     SEO   Opera   M   53  2.621474e+09      1
# 3       ATGTXKYKUDUQN     SEO  Safari   M   41  3.840542e+09      0
# 4       NAUITBZFJKHWW     Ads  Safari   M   45  4.155831e+08      0
# ...               ...     ...     ...  ..  ...           ...    ...
# 151107  XPSKTWGPWINLR     SEO  Chrome   M   28  3.451155e+09      1
# 151108  LYSFABUCPCGBA     SEO  Safari   M   32  2.439047e+09      0
# 151109  MEQHCSJUBRBFE     SEO      IE   F   26  2.748471e+09      0
# 151110  CMCXFGRHYSTVJ     SEO  Chrome   M   37  3.601175e+09      0
# 151111  ZINIADFCLHYPG  Direct      IE   M   38  4.103825e+09      0
#
#               country  time_diff  device_num
# 0               Japan      13882           1
# 1       United States      17944           1
# 2       United States          1          12
# 3                  NA      60085           1
# 4       United States      41461           1
# ...               ...        ...         ...
# 151107  United States      77233           2
# 151108    Netherlands      67270           1
# 151109          Japan      28816           1
# 151110  United States      48519           2
# 151111             NA      68493           1
#
# [151112 rows x 14 columns]

# %% [markdown]
# correction

# %%
device_num = df1[['user_id', 'device_id']].groupby('device_id').count().reset_index()

device_num = device_num.rename(columns={'user_id': 'device_num'})
df1 = df1.merge(device_num, how='left', on='device_id')
df1.head()
# Out:
#    user_id         signup_time       purchase_time  purchase_value  \
# 0    22058 2015-02-24 22:55:49 2015-04-18 02:47:11              34
# 1   333320 2015-06-07 20:39:50 2015-06-08 01:38:54              16
# 2     1359 2015-01-01 18:52:44 2015-01-01 18:52:45              15
# 3   150084 2015-04-28 21:13:25 2015-05-04 13:54:50              44
# 4   221365 2015-07-21 07:09:52 2015-09-09 18:40:53              39
#
#        device_id source browser sex  age    ip_address  ...  time_diff  \
# 0  QVPSPJUOCKZAR    SEO  Chrome   M   39  7.327584e+08  ...      13882
# 1  EOGFQPIZPYXFZ    Ads  Chrome   F   53  3.503114e+08  ...      17944
# 2  YSSKYOSJHPPLJ    SEO   Opera   M   53  2.621474e+09  ...          1
# 3  ATGTXKYKUDUQN    SEO  Safari   M   41  3.840542e+09  ...      60085
# 4  NAUITBZFJKHWW    Ads  Safari   M   45  4.155831e+08  ...      41461
#
#   device_num_x  ip_num_x  signup_day  signup_week  purchase_day  \
# 0            1         1           1            9             5
# 1            1         1           6           23             0
# 2           12        12           3            1             3
# 3            1         1           1           18             0
# 4            1         1           1           30             2
#
#    purchase_week  device_num_y  ip_num_y  device_num
# 0             16             1         1           1
# 1             24             1         1           1
# 2              1            12        12          12
# 3             19             1         1           1
# 4             37             1         1           1
#
# [5 rows x 22 columns]

# %% [markdown]
# ### Faire de même pour les `ip_address`

# %%
df1['ip_num'] = 0
g = df1.groupby('ip_address')
for(i,x) in df1.iterrows():
    if i in df1.index and x.ip_address in g.groups.keys():
        df1.loc[i,'ip_num']= g.get_group(x.ip_address).user_id.count()
df1
# Out:
#         user_id         signup_time       purchase_time  purchase_value  \
# 0         22058 2015-02-24 22:55:49 2015-04-18 02:47:11              34
# 1        333320 2015-06-07 20:39:50 2015-06-08 01:38:54              16
# 2          1359 2015-01-01 18:52:44 2015-01-01 18:52:45              15
# 3        150084 2015-04-28 21:13:25 2015-05-04 13:54:50              44
# 4        221365 2015-07-21 07:09:52 2015-09-09 18:40:53              39
# ...         ...                 ...                 ...             ...
# 151107   345170 2015-01-27 03:03:34 2015-03-29 00:30:47              43
# 151108   274471 2015-05-15 17:43:29 2015-05-26 12:24:39              35
# 151109   368416 2015-03-03 23:07:31 2015-05-20 07:07:47              40
# 151110   207709 2015-07-09 20:06:07 2015-09-07 09:34:46              46
# 151111   138208 2015-06-10 07:02:20 2015-07-21 02:03:53              20
#
#             device_id  source browser sex  age    ip_address  class  \
# 0       QVPSPJUOCKZAR     SEO  Chrome   M   39  7.327584e+08      0
# 1       EOGFQPIZPYXFZ     Ads  Chrome   F   53  3.503114e+08      0
# 2       YSSKYOSJHPPLJ     SEO   Opera   M   53  2.621474e+09      1
# 3       ATGTXKYKUDUQN     SEO  Safari   M   41  3.840542e+09      0
# 4       NAUITBZFJKHWW     Ads  Safari   M   45  4.155831e+08      0
# ...               ...     ...     ...  ..  ...           ...    ...
# 151107  XPSKTWGPWINLR     SEO  Chrome   M   28  3.451155e+09      1
# 151108  LYSFABUCPCGBA     SEO  Safari   M   32  2.439047e+09      0
# 151109  MEQHCSJUBRBFE     SEO      IE   F   26  2.748471e+09      0
# 151110  CMCXFGRHYSTVJ     SEO  Chrome   M   37  3.601175e+09      0
# 151111  ZINIADFCLHYPG  Direct      IE   M   38  4.103825e+09      0
#
#               country  time_diff  device_num  ip_num  signup_day
# 0               Japan      13882           1       1           0
# 1       United States      17944           1       1           0
# 2       United States          1          12      12           0
# 3                  NA      60085           1       1           0
# 4       United States      41461           1       1           0
# ...               ...        ...         ...     ...         ...
# 151107  United States      77233           2       1           0
# 151108    Netherlands      67270           1       1           0
# 151109          Japan      28816           1       1           0
# 151110  United States      48519           2       1           0
# 151111             NA      68493           1       1           0
#
# [151112 rows x 16 columns]

# %% [markdown]
# correction

# %%
ip_num = df1[['user_id', 'ip_address']].groupby('ip_address').count().reset_index()
ip_num = ip_num.rename(columns={'user_id': 'ip_num'})
df1 = df1.merge(ip_num, how='left', on='ip_address')

# %% [markdown]
# ### Traiter les variables `signup_time` & `purchase_time` afin de les différentier suivant la semaine et le week end

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 151112 entries, 0 to 151111
# Data columns (total 15 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   user_id         151112 non-null  int64
#  1   signup_time     151112 non-null  datetime64[ns]
#  2   purchase_time   151112 non-null  datetime64[ns]
#  3   purchase_value  151112 non-null  int64
#  4   device_id       151112 non-null  object
#  5   source          151112 non-null  object
#  6   browser         151112 non-null  object
#  7   sex             151112 non-null  object
#  8   age             151112 non-null  int64
#  9   ip_address      151112 non-null  float64
#  10  class           151112 non-null  int64
#  11  country         151112 non-null  object
#  12  time_diff       151112 non-null  int64
#  13  device_num      151112 non-null  int64
#  14  ip_num          151112 non-null  int64
# dtypes: datetime64[ns](2), float64(1), int64(7), object(5)
# memory usage: 17.3+ MB

# %%
df1['signup_day'] = 0
signup_day = df1.signup_time.dt.dayofweek
df1['signup_day'] = signup_day
df1
# Out:
#         user_id         signup_time       purchase_time  purchase_value  \
# 0         22058 2015-02-24 22:55:49 2015-04-18 02:47:11              34
# 1        333320 2015-06-07 20:39:50 2015-06-08 01:38:54              16
# 2          1359 2015-01-01 18:52:44 2015-01-01 18:52:45              15
# 3        150084 2015-04-28 21:13:25 2015-05-04 13:54:50              44
# 4        221365 2015-07-21 07:09:52 2015-09-09 18:40:53              39
# ...         ...                 ...                 ...             ...
# 151107   345170 2015-01-27 03:03:34 2015-03-29 00:30:47              43
# 151108   274471 2015-05-15 17:43:29 2015-05-26 12:24:39              35
# 151109   368416 2015-03-03 23:07:31 2015-05-20 07:07:47              40
# 151110   207709 2015-07-09 20:06:07 2015-09-07 09:34:46              46
# 151111   138208 2015-06-10 07:02:20 2015-07-21 02:03:53              20
#
#             device_id  source browser sex  age    ip_address  class  \
# 0       QVPSPJUOCKZAR     SEO  Chrome   M   39  7.327584e+08      0
# 1       EOGFQPIZPYXFZ     Ads  Chrome   F   53  3.503114e+08      0
# 2       YSSKYOSJHPPLJ     SEO   Opera   M   53  2.621474e+09      1
# 3       ATGTXKYKUDUQN     SEO  Safari   M   41  3.840542e+09      0
# 4       NAUITBZFJKHWW     Ads  Safari   M   45  4.155831e+08      0
# ...               ...     ...     ...  ..  ...           ...    ...
# 151107  XPSKTWGPWINLR     SEO  Chrome   M   28  3.451155e+09      1
# 151108  LYSFABUCPCGBA     SEO  Safari   M   32  2.439047e+09      0
# 151109  MEQHCSJUBRBFE     SEO      IE   F   26  2.748471e+09      0
# 151110  CMCXFGRHYSTVJ     SEO  Chrome   M   37  3.601175e+09      0
# 151111  ZINIADFCLHYPG  Direct      IE   M   38  4.103825e+09      0
#
#               country  time_diff  device_num  ip_num  signup_day  signup_week
# 0               Japan      13882           1       1           1            9
# 1       United States      17944           1       1           6           23
# 2       United States          1          12      12           3            1
# 3                  NA      60085           1       1           1           18
# 4       United States      41461           1       1           1           30
# ...               ...        ...         ...     ...         ...          ...
# 151107  United States      77233           2       1           1            5
# 151108    Netherlands      67270           1       1           4           20
# 151109          Japan      28816           1       1           1           10
# 151110  United States      48519           2       1           3           28
# 151111             NA      68493           1       1           2           24
#
# [151112 rows x 17 columns]

# %%
df1['signup_week'] = 0
df1.signup_week = df1.signup_time.dt.week
df1
# Out:
# <ipython-input-74-48cdb81970a5>:2: FutureWarning: Series.dt.weekofyear and Series.dt.week have been deprecated.  Please use Series.dt.isocalendar().week instead.
#   df1.signup_week = df1.signup_time.dt.week
#         user_id         signup_time       purchase_time  purchase_value  \
# 0         22058 2015-02-24 22:55:49 2015-04-18 02:47:11              34
# 1        333320 2015-06-07 20:39:50 2015-06-08 01:38:54              16
# 2          1359 2015-01-01 18:52:44 2015-01-01 18:52:45              15
# 3        150084 2015-04-28 21:13:25 2015-05-04 13:54:50              44
# 4        221365 2015-07-21 07:09:52 2015-09-09 18:40:53              39
# ...         ...                 ...                 ...             ...
# 151107   345170 2015-01-27 03:03:34 2015-03-29 00:30:47              43
# 151108   274471 2015-05-15 17:43:29 2015-05-26 12:24:39              35
# 151109   368416 2015-03-03 23:07:31 2015-05-20 07:07:47              40
# 151110   207709 2015-07-09 20:06:07 2015-09-07 09:34:46              46
# 151111   138208 2015-06-10 07:02:20 2015-07-21 02:03:53              20
#
#             device_id  source browser sex  age    ip_address  class  \
# 0       QVPSPJUOCKZAR     SEO  Chrome   M   39  7.327584e+08      0
# 1       EOGFQPIZPYXFZ     Ads  Chrome   F   53  3.503114e+08      0
# 2       YSSKYOSJHPPLJ     SEO   Opera   M   53  2.621474e+09      1
# 3       ATGTXKYKUDUQN     SEO  Safari   M   41  3.840542e+09      0
# 4       NAUITBZFJKHWW     Ads  Safari   M   45  4.155831e+08      0
# ...               ...     ...     ...  ..  ...           ...    ...
# 151107  XPSKTWGPWINLR     SEO  Chrome   M   28  3.451155e+09      1
# 151108  LYSFABUCPCGBA     SEO  Safari   M   32  2.439047e+09      0
# 151109  MEQHCSJUBRBFE     SEO      IE   F   26  2.748471e+09      0
# 151110  CMCXFGRHYSTVJ     SEO  Chrome   M   37  3.601175e+09      0
# 151111  ZINIADFCLHYPG  Direct      IE   M   38  4.103825e+09      0
#
#               country  time_diff  device_num  ip_num  signup_day  signup_week
# 0               Japan      13882           1       1           1            9
# 1       United States      17944           1       1           6           23
# 2       United States          1          12      12           3            1
# 3                  NA      60085           1       1           1           18
# 4       United States      41461           1       1           1           30
# ...               ...        ...         ...     ...         ...          ...
# 151107  United States      77233           2       1           1            5
# 151108    Netherlands      67270           1       1           4           20
# 151109          Japan      28816           1       1           1           10
# 151110  United States      48519           2       1           3           28
# 151111             NA      68493           1       1           2           24
#
# [151112 rows x 17 columns]

# %%
df1['purchase_day'] = 0
df1.purchase_day = df1.purchase_time.dt.dayofweek
df1['purchase_week'] = 0
df1.purchase_week = df1.purchase_time.dt.week
df1
# Out:
# <ipython-input-76-313f0be64a55>:4: FutureWarning: Series.dt.weekofyear and Series.dt.week have been deprecated.  Please use Series.dt.isocalendar().week instead.
#   df1.purchase_week = df1.purchase_time.dt.week
#         user_id         signup_time       purchase_time  purchase_value  \
# 0         22058 2015-02-24 22:55:49 2015-04-18 02:47:11              34
# 1        333320 2015-06-07 20:39:50 2015-06-08 01:38:54              16
# 2          1359 2015-01-01 18:52:44 2015-01-01 18:52:45              15
# 3        150084 2015-04-28 21:13:25 2015-05-04 13:54:50              44
# 4        221365 2015-07-21 07:09:52 2015-09-09 18:40:53              39
# ...         ...                 ...                 ...             ...
# 151107   345170 2015-01-27 03:03:34 2015-03-29 00:30:47              43
# 151108   274471 2015-05-15 17:43:29 2015-05-26 12:24:39              35
# 151109   368416 2015-03-03 23:07:31 2015-05-20 07:07:47              40
# 151110   207709 2015-07-09 20:06:07 2015-09-07 09:34:46              46
# 151111   138208 2015-06-10 07:02:20 2015-07-21 02:03:53              20
#
#             device_id  source browser sex  age    ip_address  class  \
# 0       QVPSPJUOCKZAR     SEO  Chrome   M   39  7.327584e+08      0
# 1       EOGFQPIZPYXFZ     Ads  Chrome   F   53  3.503114e+08      0
# 2       YSSKYOSJHPPLJ     SEO   Opera   M   53  2.621474e+09      1
# 3       ATGTXKYKUDUQN     SEO  Safari   M   41  3.840542e+09      0
# 4       NAUITBZFJKHWW     Ads  Safari   M   45  4.155831e+08      0
# ...               ...     ...     ...  ..  ...           ...    ...
# 151107  XPSKTWGPWINLR     SEO  Chrome   M   28  3.451155e+09      1
# 151108  LYSFABUCPCGBA     SEO  Safari   M   32  2.439047e+09      0
# 151109  MEQHCSJUBRBFE     SEO      IE   F   26  2.748471e+09      0
# 151110  CMCXFGRHYSTVJ     SEO  Chrome   M   37  3.601175e+09      0
# 151111  ZINIADFCLHYPG  Direct      IE   M   38  4.103825e+09      0
#
#               country  time_diff  device_num  ip_num  signup_day  signup_week  \
# 0               Japan      13882           1       1           1            9
# 1       United States      17944           1       1           6           23
# 2       United States          1          12      12           3            1
# 3                  NA      60085           1       1           1           18
# 4       United States      41461           1       1           1           30
# ...               ...        ...         ...     ...         ...          ...
# 151107  United States      77233           2       1           1            5
# 151108    Netherlands      67270           1       1           4           20
# 151109          Japan      28816           1       1           1           10
# 151110  United States      48519           2       1           3           28
# 151111             NA      68493           1       1           2           24
#
#         purchase_day  purchase_week
# 0                  5             16
# 1                  0             24
# 2                  3              1
# 3                  0             19
# 4                  2             37
# ...              ...            ...
# 151107             6             13
# 151108             1             22
# 151109             2             21
# 151110             0             37
# 151111             1             30
#
# [151112 rows x 19 columns]

# %% [markdown]
# correction

# %%
# Signup day and week
df1['signup_day'] = df1['signup_time'].apply(lambda x: x.dayofweek)
df1['signup_week'] = df1['signup_time'].apply(lambda x: x.week)
# Purchase day and week
df1['purchase_day'] = df1['purchase_time'].apply(lambda x: x.dayofweek)
df1['purchase_week'] = df1['purchase_time'].apply(lambda x: x.week)

# %%
# Define features and target to be used
columns = ['signup_day', 'signup_week', 'purchase_day', 'purchase_week', 'purchase_value', 'source', 
           'browser', 'sex', 'age', 'country', 'time_diff', 'device_num', 'ip_num', 'class']
df1 = df1[columns]
df1.head()
# Out:
#    signup_day  signup_week  purchase_day  purchase_week  purchase_value  \
# 0           1            9             5             16              34
# 1           6           23             0             24              16
# 2           3            1             3              1              15
# 3           1           18             0             19              44
# 4           1           30             2             37              39
#
#   source browser sex  age        country  time_diff  device_num  ip_num  class
# 0    SEO  Chrome   M   39          Japan      13882           1       1      0
# 1    Ads  Chrome   F   53  United States      17944           1       1      0
# 2    SEO   Opera   M   53  United States          1          12      12      1
# 3    SEO  Safari   M   41             NA      60085           1       1      0
# 4    Ads  Safari   M   45  United States      41461           1       1      0

# %% [markdown]
# ### Définir vos variables de travail (X,y)

# %%
X = df1[['signup_day','signup_week','purchase_day','purchase_week','purchase_value','source','browser','sex','age','country','time_diff','device_num','ip_num']]
y = df1['class']

# %% [markdown]
# ### Afficher les informations du dataset afin de vizualiser les variables numeriques et categoriques

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 151112 entries, 0 to 151111
# Data columns (total 14 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   signup_day      151112 non-null  int64
#  1   signup_week     151112 non-null  int64
#  2   purchase_day    151112 non-null  int64
#  3   purchase_week   151112 non-null  int64
#  4   purchase_value  151112 non-null  int64
#  5   source          151112 non-null  int64
#  6   browser         151112 non-null  int64
#  7   sex             151112 non-null  int64
#  8   age             151112 non-null  int64
#  9   country         151112 non-null  int64
#  10  time_diff       151112 non-null  int64
#  11  device_num      151112 non-null  int64
#  12  ip_num          151112 non-null  int64
#  13  class           151112 non-null  int64
# dtypes: int64(14)
# memory usage: 17.3 MB

# %% [markdown]
# ### Traiter les variables catégoriques

# %%
from sklearn import preprocessing
le = preprocessing.LabelEncoder()
le.fit(df1.source)
df1.source = le.transform(df1.source)
df1.head()
# Out:
#    signup_day  signup_week  purchase_day  purchase_week  purchase_value  \
# 0           1            9             5             16              34
# 1           6           23             0             24              16
# 2           3            1             3              1              15
# 3           1           18             0             19              44
# 4           1           30             2             37              39
#
#    source browser sex  age        country  time_diff  device_num  ip_num  \
# 0       2  Chrome   M   39          Japan      13882           1       1
# 1       0  Chrome   F   53  United States      17944           1       1
# 2       2   Opera   M   53  United States          1          12      12
# 3       2  Safari   M   41             NA      60085           1       1
# 4       0  Safari   M   45  United States      41461           1       1
#
#    class
# 0      0
# 1      0
# 2      1
# 3      0
# 4      0

# %%
le.fit(df1.browser)
df1.browser = le.transform(df1.browser)
df1.head()
# Out:
#    signup_day  signup_week  purchase_day  purchase_week  purchase_value  \
# 0           1            9             5             16              34
# 1           6           23             0             24              16
# 2           3            1             3              1              15
# 3           1           18             0             19              44
# 4           1           30             2             37              39
#
#    source  browser sex  age        country  time_diff  device_num  ip_num  \
# 0       2        0   M   39          Japan      13882           1       1
# 1       0        0   F   53  United States      17944           1       1
# 2       2        3   M   53  United States          1          12      12
# 3       2        4   M   41             NA      60085           1       1
# 4       0        4   M   45  United States      41461           1       1
#
#    class
# 0      0
# 1      0
# 2      1
# 3      0
# 4      0

# %%
le.fit(df1.country)
df1.country = le.transform(df1.country)
df1.head()
# Out:
#    signup_day  signup_week  purchase_day  purchase_week  purchase_value  \
# 0           1            9             5             16              34
# 1           6           23             0             24              16
# 2           3            1             3              1              15
# 3           1           18             0             19              44
# 4           1           30             2             37              39
#
#    source  browser sex  age  country  time_diff  device_num  ip_num  class
# 0       2        0   M   39       84      13882           1       1      0
# 1       0        0   F   53      172      17944           1       1      0
# 2       2        3   M   53      172          1          12      12      1
# 3       2        4   M   41      115      60085           1       1      0
# 4       0        4   M   45      172      41461           1       1      0

# %%
le.fit(df1.sex)
df1.sex = le.transform(df1.sex)
df1.head()
# Out:
#    signup_day  signup_week  purchase_day  purchase_week  purchase_value  \
# 0           1            9             5             16              34
# 1           6           23             0             24              16
# 2           3            1             3              1              15
# 3           1           18             0             19              44
# 4           1           30             2             37              39
#
#    source  browser  sex  age  country  time_diff  device_num  ip_num  class
# 0       2        0    1   39       84      13882           1       1      0
# 1       0        0    0   53      172      17944           1       1      0
# 2       2        3    1   53      172          1          12      12      1
# 3       2        4    1   41      115      60085           1       1      0
# 4       0        4    1   45      172      41461           1       1      0

# %% [markdown]
# ### Spliter vos variables

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.30, random_state=42)

# %% [markdown]
# ### Instancier un `RandomForestClassifier` et l'entrainer sur vos données

# %%
from sklearn.ensemble import RandomForestClassifier
clf = RandomForestClassifier(n_estimators=100)
clf.fit(X_train,y_train)
# Out:
# RandomForestClassifier()

# %%
y_pred = clf.predict(X_test)

# %% [markdown]
# ### Afficher l'accuracy moyenne pour 10 'fold cross validation'

# %%
from sklearn.model_selection import cross_val_score
scores = cross_val_score(clf, X_train, y_train, scoring='accuracy').mean()
scores
# Out:
# 0.9559927336781131

# %% [markdown]
# ### Afficher les `feature_importances_`

# %%
feature_imp = pd.Series(clf.feature_importances_,index=columns[:-1]).sort_values(ascending=False)
feature_imp
# Out:
# time_diff         0.303197
# ip_num            0.269970
# purchase_week     0.198716
# device_num        0.120067
# signup_week       0.096616
# age               0.004916
# country           0.003312
# purchase_value    0.001858
# purchase_day      0.000699
# signup_day        0.000537
# browser           0.000087
# source            0.000021
# sex               0.000005
# dtype: float64

# %% [markdown]
# ### Vizualiser les sur un graphique

# %% [markdown]
# ### Afficher le `Classification report`

# %%
from sklearn.metrics import classification_report
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.96      1.00      0.98     41117
#            1       1.00      0.54      0.70      4217
#
#     accuracy                           0.96     45334
#    macro avg       0.98      0.77      0.84     45334
# weighted avg       0.96      0.96      0.95     45334

# %% [markdown]
# ### Traçer la courbe AUC

# %% [markdown]
# ### Afficher la matrice de confusion
# Qu'en pensez vous ?

# %% [markdown]
# ### Faire une selection de certaine variables et spliter vos varibales

# %% [markdown]
# ### Entrainer un classifieur `LogisticRegression` sur ces variables
