# %% [markdown]
# # Data Visualisation Statistiques descriptives

# %% [markdown]
# ## Visualisation d’un nuage de points et exploration des variables

# %% [markdown]
# #### 1.Importez les librairies qu’il nous faut (pandas, seaborn, matplotlib, numpy)

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt 
import seaborn as sns

# %% [markdown]
# #### 2.Donnez la liste des variables présentes dans ce dataset ainsi que leur nature (sont elles qualitatives, quantitatives, discrète etc...) et leur type (float, int, str etc...)

# %%
df = pd.read_csv('./data/house_pricing.csv')
df
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0        1          60       RL         65.0     8450   Pave   NaN      Reg
# 1        2          20       RL         80.0     9600   Pave   NaN      Reg
# 2        3          60       RL         68.0    11250   Pave   NaN      IR1
# 3        4          70       RL         60.0     9550   Pave   NaN      IR1
# 4        5          60       RL         84.0    14260   Pave   NaN      IR1
# ...    ...         ...      ...          ...      ...    ...   ...      ...
# 1455  1456          60       RL         62.0     7917   Pave   NaN      Reg
# 1456  1457          20       RL         85.0    13175   Pave   NaN      Reg
# 1457  1458          70       RL         66.0     9042   Pave   NaN      Reg
# 1458  1459          20       RL         68.0     9717   Pave   NaN      Reg
# 1459  1460          20       RL         75.0     9937   Pave   NaN      Reg
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1460 entries, 0 to 1459
# Data columns (total 81 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             1460 non-null   int64
#  1   MSSubClass     1460 non-null   int64
#  2   MSZoning       1460 non-null   object
#  3   LotFrontage    1201 non-null   float64
#  4   LotArea        1460 non-null   int64
#  5   Street         1460 non-null   object
#  6   Alley          91 non-null     object
#  7   LotShape       1460 non-null   object
#  8   LandContour    1460 non-null   object
#  9   Utilities      1460 non-null   object
#  10  LotConfig      1460 non-null   object
#  11  LandSlope      1460 non-null   object
#  12  Neighborhood   1460 non-null   object
#  13  Condition1     1460 non-null   object
#  14  Condition2     1460 non-null   object
#  15  BldgType       1460 non-null   object
#  16  HouseStyle     1460 non-null   object
# ...

# %% [markdown]
# #### 3.En créant un nuage de points, regardez comment se comporte la colonne LotArea par rapport au SalesPrices

# %%
sns.regplot(x="LotArea", y="SalePrice" , data= df , fit_reg=False)
# Out:
# <AxesSubplot:xlabel='LotArea', ylabel='SalePrice'>

# %% [markdown]
# #### 4.Affinez votre visualisation en ne gardant uniquement les maisons qui ont un LotArea inférieur à 20 000 pieds carrés et un prix inférieur à 500 000

# %%
sns.regplot(x="LotArea", y="SalePrice" , data= df , fit_reg=False)
plt.ylim(0,50000)
plt.xlim(0,20000)
# Out:
# (0.0, 20000.0)

# %% [markdown]
# ### correction

# %%
hp_data = pd.read_csv('./data/house_pricing.csv')
toto = hp_data[hp_data < 20000]
toto = toto[toto["SalePRice"] < 500000]
sns.scatterplot(data=toto , x="LotArea", y="SalePrice")
# Out:
# <AxesSubplot:xlabel='LotArea', ylabel='SalePrice'>

# %%
hp_data = pd.read_csv('./data/house_pricing.csv')
sns.scatterplot(data=hp_data[(hp_data["LotArea"] < 20000)&(hp_data["SalePrice"] < 500000)] , x="LotArea", y="SalePrice")
# Out:
# <AxesSubplot:xlabel='LotArea', ylabel='SalePrice'>

# %% [markdown]
# #### 5.En créant un nuage de points, regardez la relation entre le LotFrontage et le LotArea

# %%
sns.regplot(x="LotFrontage", y="LotArea" , data=df , fit_reg=False)
# Out:
# <AxesSubplot:xlabel='LotFrontage', ylabel='LotArea'>

# %% [markdown]
# #### 6.De la même manière, affinez votre visualisation en ne gardant uniquement les maisons qui ont un LotFrontage inférieur à 200 pieds carrés et un LotArea inférieur à 100000 pieds carré

# %%
df = pd.read_csv('./data/house_pricing.csv')
sns.regplot(x="LotFrontage", y="LotArea" , data=df , fit_reg=False)
plt.ylim(0,100000)
plt.xlim(0,200)
# Out:
# (0.0, 200.0)

# %% [markdown]
# correction

# %%
hp_data = pd.read_csv('./data/house_pricing.csv')
sns.scatterplot(data=hp_data[(hp_data["LotArea"] < 100000)&(hp_data["LotFrontage"] < 200)] , x="LotFrontage", y="LotArea")
# Out:
# <AxesSubplot:xlabel='LotFrontage', ylabel='LotArea'>

# %% [markdown]
# ## Visualisation de relations continues

# %% [markdown]
# #### 1) Importez les librairies qu’il vous faut

# %%
pred = pd.read_csv('./data/sales_predictions.csv')
pred
# Out:
#                date  date_block_num  shop_id  item_id  item_price  \
# 0        02.01.2013               0       59    22154      999.00
# 1        03.01.2013               0       25     2552      899.00
# 2        05.01.2013               0       25     2552      899.00
# 3        06.01.2013               0       25     2554     1709.05
# 4        15.01.2013               0       25     2555     1099.00
# ...             ...             ...      ...      ...         ...
# 2935844  10.10.2015              33       25     7409      299.00
# 2935845  09.10.2015              33       25     7460      299.00
# 2935846  14.10.2015              33       25     7459      349.00
# 2935847  22.10.2015              33       25     7440      299.00
# 2935848  03.10.2015              33       25     7460      299.00
#
#          item_cnt_day
# 0                 1.0
# 1                 1.0
# 2                -1.0
# 3                 1.0
# 4                 1.0
# ...               ...
# ...

# %%
pred.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2935849 entries, 0 to 2935848
# Data columns (total 6 columns):
#  #   Column          Dtype
# ---  ------          -----
#  0   date            object
#  1   date_block_num  int64
#  2   shop_id         int64
#  3   item_id         int64
#  4   item_price      float64
#  5   item_cnt_day    float64
# dtypes: float64(2), int64(3), object(1)
# memory usage: 134.4+ MB

# %% [markdown]
# #### 2) En utilisant relplot(), construisez un graphique qui va vous permettre de voir l’évolutiondes prix par rapport au temps. Que pouvez vous voir ?

# %%
g = sns.relplot(data=pred , x="date",y="item_price")

# %% [markdown]
# #### 3) Corrigeons le problème de visualisation, en utilisant la fonction .sample() de Pandas, prenez un échantillons de 50 éléments dans votre dataset

# %%
g = sns.relplot(data=pred.sample(50) , x="date",y="item_price")

# %% [markdown]
# #### 4)Retentez de faire votre visualisation, créez une figure de taille (20,6). Que voyez vous ?

# %%
#plt.figure(figsize=(20,6))
g = sns.relplot(data=pred.sample(50) , x="date",y="item_price" , height=8,aspect=3)

# %% [markdown]
# #### 5) En utilisant la fonction pd.to_datetime(), convertissez votre colonne date en datetime

# %%
pred.date = pd.to_datetime(pred.date)
#plt.figure(figsize=(20,6))
g = sns.relplot(data=pred.sample(50) , x="date",y="item_price", height=8,aspect=3)

# %% [markdown]
# ## Visualisation de variables catégoriques

# %% [markdown]
# #### 1) Importez les librairies qu’il vous faut

# %%
ibm = pd.read_csv('./data/IBM_HR_ATTRITION.csv')
ibm
# Out:
#       Age Attrition     BusinessTravel  DailyRate              Department  \
# 0      41       Yes      Travel_Rarely       1102                   Sales
# 1      49        No  Travel_Frequently        279  Research & Development
# 2      37       Yes      Travel_Rarely       1373  Research & Development
# 3      33        No  Travel_Frequently       1392  Research & Development
# 4      27        No      Travel_Rarely        591  Research & Development
# ...   ...       ...                ...        ...                     ...
# 1465   36        No  Travel_Frequently        884  Research & Development
# 1466   39        No      Travel_Rarely        613  Research & Development
# 1467   27        No      Travel_Rarely        155  Research & Development
# 1468   49        No  Travel_Frequently       1023                   Sales
# 1469   34        No      Travel_Rarely        628  Research & Development
#
#       DistanceFromHome  Education EducationField  EmployeeCount  \
# ...

# %%
ibm.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1470 entries, 0 to 1469
# Data columns (total 35 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Age                       1470 non-null   int64
#  1   Attrition                 1470 non-null   object
#  2   BusinessTravel            1470 non-null   object
#  3   DailyRate                 1470 non-null   int64
#  4   Department                1470 non-null   object
#  5   DistanceFromHome          1470 non-null   int64
#  6   Education                 1470 non-null   int64
#  7   EducationField            1470 non-null   object
#  8   EmployeeCount             1470 non-null   int64
#  9   EmployeeNumber            1470 non-null   int64
#  10  EnvironmentSatisfaction   1470 non-null   int64
#  11  Gender                    1470 non-null   object
#  12  HourlyRate                1470 non-null   int64
#  13  JobInvolvement            1470 non-null   int64
# ...

# %% [markdown]
# #### 2) En utilisant catplot(), construisez un graphique qui vous permette de voir la distribution des personnes qui ont quitté l’entreprise par rapport à leur JobSatisfaction

# %%
ibm
g = sns.catplot(x="Attrition",y="JobSatisfaction",data=ibm)

# %% [markdown]
# #### 3) Changez de graphique et utilisez plutôt un boxplot, que pouvez vous conclure ?

# %%
g = sns.boxplot(x="Attrition",y="JobSatisfaction",data=ibm)

# %% [markdown]
# #### 4) Peut-on dire grâce aux boxplot si une variable présente des valeurs aberrantes ?

# %% [markdown]
# Oui, on peut dire grâce aux boxplot si une variable présent des valeurs aberrantes.
# Dans le graphique ci-dessus on ne vois pas de valeurs abérantes.

# %% [markdown]
# #### 5) Isolez les observations présentant des valeurs aberrantes pour la variable JobSatisfaction en fonction de la variable indiquant si ils ont quitté l’entreprise ou nom

# %% [markdown]
# #### 6) Utilisez la méthode .describe de pandas pour obtenir un tableau récapitulatif des statistiques descriptives du dataset.

# %%
ibm.describe()
# Out:
#                Age    DailyRate  DistanceFromHome    Education  EmployeeCount  \
# count  1470.000000  1470.000000       1470.000000  1470.000000         1470.0
# mean     36.923810   802.485714          9.192517     2.912925            1.0
# std       9.135373   403.509100          8.106864     1.024165            0.0
# min      18.000000   102.000000          1.000000     1.000000            1.0
# 25%      30.000000   465.000000          2.000000     2.000000            1.0
# 50%      36.000000   802.000000          7.000000     3.000000            1.0
# 75%      43.000000  1157.000000         14.000000     4.000000            1.0
# max      60.000000  1499.000000         29.000000     5.000000            1.0
#
#        EmployeeNumber  EnvironmentSatisfaction   HourlyRate  JobInvolvement  \
# count     1470.000000              1470.000000  1470.000000     1470.000000
# mean      1024.865306                 2.721769    65.891156        2.729932
# ...

# %% [markdown]
# #### 7) Comparez les individus présentant des valeurs aberrantes pour la variable JobSatisfaction avec les statistiques descriptives du dataset, remarquez vous des différences notoires ?

# %% [markdown]
# #### 8) Faites de même avec le TotalWorkingYears. Que pouvez vous conclure ?

# %%
g = sns.boxplot(x="Attrition",y="TotalWorkingYears",data=ibm)

# %%
g = sns.boxplot(x="Attrition",y="TotalWorkingYears",data=ibm[ibm['TotalWorkingYears']<20])

# %% [markdown]
# #### 9) Remplacer les valeurs de la colonne Attrition par 1 pour Yes et 0 pour No

# %%
ibm.Attrition = ibm.Attrition.replace(to_replace = ["Yes", "No"], value=[1,0])
g = sns.boxplot(x="Attrition",y="TotalWorkingYears",data=ibm[ibm['TotalWorkingYears']<20])

# %% [markdown]
# #### 10) En utilisant un Histogramme, regardez la répartition du taux de départ par EducationField

# %%
sns.catplot(x="EducationField", y="Attrition", data= ibm, kind="bar", height=10)

# %% [markdown]
# ## Visualisation d’une distribution

# %% [markdown]
# #### 1) Importez les librairies qu’il vous faut

# %%
ibm
# Out:
#       Age Attrition     BusinessTravel  DailyRate              Department  \
# 0      41       Yes      Travel_Rarely       1102                   Sales
# 1      49        No  Travel_Frequently        279  Research & Development
# 2      37       Yes      Travel_Rarely       1373  Research & Development
# 3      33        No  Travel_Frequently       1392  Research & Development
# 4      27        No      Travel_Rarely        591  Research & Development
# ...   ...       ...                ...        ...                     ...
# 1465   36        No  Travel_Frequently        884  Research & Development
# 1466   39        No      Travel_Rarely        613  Research & Development
# 1467   27        No      Travel_Rarely        155  Research & Development
# 1468   49        No  Travel_Frequently       1023                   Sales
# 1469   34        No      Travel_Rarely        628  Research & Development
#
#       DistanceFromHome  Education EducationField  EmployeeCount  \
# ...

# %%
ibm.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1470 entries, 0 to 1469
# Data columns (total 35 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Age                       1470 non-null   int64
#  1   Attrition                 1470 non-null   object
#  2   BusinessTravel            1470 non-null   object
#  3   DailyRate                 1470 non-null   int64
#  4   Department                1470 non-null   object
#  5   DistanceFromHome          1470 non-null   int64
#  6   Education                 1470 non-null   int64
#  7   EducationField            1470 non-null   object
#  8   EmployeeCount             1470 non-null   int64
#  9   EmployeeNumber            1470 non-null   int64
#  10  EnvironmentSatisfaction   1470 non-null   int64
#  11  Gender                    1470 non-null   object
#  12  HourlyRate                1470 non-null   int64
#  13  JobInvolvement            1470 non-null   int64
# ...

# %%
ibm.describe()
# Out:
#                Age    DailyRate  DistanceFromHome    Education  EmployeeCount  \
# count  1470.000000  1470.000000       1470.000000  1470.000000         1470.0
# mean     36.923810   802.485714          9.192517     2.912925            1.0
# std       9.135373   403.509100          8.106864     1.024165            0.0
# min      18.000000   102.000000          1.000000     1.000000            1.0
# 25%      30.000000   465.000000          2.000000     2.000000            1.0
# 50%      36.000000   802.000000          7.000000     3.000000            1.0
# 75%      43.000000  1157.000000         14.000000     4.000000            1.0
# max      60.000000  1499.000000         29.000000     5.000000            1.0
#
#        EmployeeNumber  EnvironmentSatisfaction   HourlyRate  JobInvolvement  \
# count     1470.000000              1470.000000  1470.000000     1470.000000
# mean      1024.865306                 2.721769    65.891156        2.729932
# ...

# %% [markdown]
# #### 2) En utilisant distplot(), construisez un graphique qui permette de voir la distribution des revenues par mois chez IBM (MonthlyIncome)

# %%
ibm.MonthlyIncome.describe()
# Out:
# count     1470.000000
# mean      6502.931293
# std       4707.956783
# min       1009.000000
# 25%       2911.000000
# 50%       4919.000000
# 75%       8379.000000
# max      19999.000000
# Name: MonthlyIncome, dtype: float64

# %%
sns.distplot(ibm["MonthlyIncome"])
# Out:
# /Users/prinda/Library/Python/3.8/lib/python/site-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='MonthlyIncome', ylabel='Density'>

# %% [markdown]
# #### 3) On peut voir que les très haut salaires biaisent notre distribution, essayons de voir ladistribution des salaires entre 0 et 5000 / mois

# %%
sns.distplot(ibm["MonthlyIncome"][ibm["MonthlyIncome"]<5000])
# Out:
# /Users/prinda/Library/Python/3.8/lib/python/site-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='MonthlyIncome', ylabel='Density'>

# %% [markdown]
# ## Visualisation d’une relation linéaire

# %% [markdown]
# #### 2) On voudrait connaître la probabilité de partir de la l’entreprise par rapport à la distance par rapport à la maison. Utilisez lmplot() pour visualiser cela. Que pouvez vous conclure ?

# %%
ibm.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1470 entries, 0 to 1469
# Data columns (total 35 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Age                       1470 non-null   int64
#  1   Attrition                 1470 non-null   object
#  2   BusinessTravel            1470 non-null   object
#  3   DailyRate                 1470 non-null   int64
#  4   Department                1470 non-null   object
#  5   DistanceFromHome          1470 non-null   int64
#  6   Education                 1470 non-null   int64
#  7   EducationField            1470 non-null   object
#  8   EmployeeCount             1470 non-null   int64
#  9   EmployeeNumber            1470 non-null   int64
#  10  EnvironmentSatisfaction   1470 non-null   int64
#  11  Gender                    1470 non-null   object
#  12  HourlyRate                1470 non-null   int64
#  13  JobInvolvement            1470 non-null   int64
# ...

# %%
sns.lmplot(data=ibm, x="DistanceFromHome",y="Attrition")

# %% [markdown]
# on constate que plus une personne habite loins plus ya des chance qu'elle quitte l'entreprise.

# %% [markdown]
# #### 3) Tentez le cette fois avec le nombre d’années passées avec le Manager (YearsWithCurrManager), que pouvez vous conclure ?

# %%
sns.lmplot(data=ibm, x="YearsWithCurrManager",y="Attrition")

# %% [markdown]
# on constate que quand une personne est proche de son manager moins elle a de chance de quitter l'entreprise

# %% [markdown]
# ## Visualisation d’une heatmap

# %% [markdown]
# #### 1) Importez les librairies habituelles

# %%
df = pd.read_csv('./data/house_pricing.csv')

# %% [markdown]
# #### 2) Découpez votre dataset pour ne garder que les 15 dernieres colonnes

# %%
df = df.tail(15)
df
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 1445  1446          85       RL         70.0     8400   Pave   NaN      Reg
# 1446  1447          20       RL          NaN    26142   Pave   NaN      IR1
# 1447  1448          60       RL         80.0    10000   Pave   NaN      Reg
# 1448  1449          50       RL         70.0    11767   Pave   NaN      Reg
# 1449  1450         180       RM         21.0     1533   Pave   NaN      Reg
# 1450  1451          90       RL         60.0     9000   Pave   NaN      Reg
# 1451  1452          20       RL         78.0     9262   Pave   NaN      Reg
# 1452  1453         180       RM         35.0     3675   Pave   NaN      Reg
# 1453  1454          20       RL         90.0    17217   Pave   NaN      Reg
# 1454  1455          20       FV         62.0     7500   Pave  Pave      Reg
# 1455  1456          60       RL         62.0     7917   Pave   NaN      Reg
# ...

# %% [markdown]
# #### 3) Créez une matrice de corrélation avec toutes les variables du Dataset

# %%
corr_df = df.corr()
corr_df
# Out:
#                          Id  MSSubClass  LotFrontage   LotArea   OverallQual  \
# Id             1.000000e+00   -0.299933     0.170671 -0.176641 -2.820443e-16
# MSSubClass    -2.999333e-01    1.000000    -0.879089 -0.643601 -2.135655e-01
# LotFrontage    1.706710e-01   -0.879089     1.000000  0.914186  2.928409e-01
# LotArea       -1.766413e-01   -0.643601     0.914186  1.000000 -1.544585e-01
# OverallQual   -2.820443e-16   -0.213565     0.292841 -0.154458  1.000000e+00
# OverallCond    1.479836e-01    0.051806    -0.176484  0.150015 -1.694586e-01
# YearBuilt      3.847864e-02    0.052251     0.019051 -0.148001  4.729485e-01
# YearRemodAdd   3.193971e-01   -0.124680     0.211581 -0.204825  3.828724e-01
# MasVnrArea    -3.907955e-01   -0.121045     0.279790  0.251578  5.706548e-01
# BsmtFinSF1    -2.039226e-02    0.098483    -0.049288  0.026653  2.180785e-01
# BsmtFinSF2     2.372469e-01   -0.198927     0.142105 -0.058416 -1.765379e-01
# ...

# %% [markdown]
# correction

# %%
hp = pd.read_csv('./data/house_pricing.csv')
corr = hp.iloc[:,-15:].corr()
corr
# Out:
#                WoodDeckSF  OpenPorchSF  EnclosedPorch  3SsnPorch  ScreenPorch  \
# WoodDeckSF       1.000000     0.058661      -0.125989  -0.032771    -0.074181
# OpenPorchSF      0.058661     1.000000      -0.093079  -0.005842     0.074304
# EnclosedPorch   -0.125989    -0.093079       1.000000  -0.037305    -0.082864
# 3SsnPorch       -0.032771    -0.005842      -0.037305   1.000000    -0.031436
# ScreenPorch     -0.074181     0.074304      -0.082864  -0.031436     1.000000
# PoolArea         0.073378     0.060762       0.054203  -0.007992     0.051307
# MiscVal         -0.009551    -0.018584       0.018361   0.000354     0.031946
# MoSold           0.021011     0.071255      -0.028887   0.029474     0.023217
# YrSold           0.022270    -0.057619      -0.009916   0.018645     0.010694
# SalePrice        0.324413     0.315856      -0.128578   0.044584     0.111447
#
#                PoolArea   MiscVal    MoSold    YrSold  SalePrice
# ...

# %% [markdown]
# #### 4) Créez une heatmap avec les différentes valeur de corrélation

# %%
sns.heatmap(corr)
# Out:
# <AxesSubplot:>

# %% [raw]
# correction

# %%
f, ax = plt.subplots(figsize=(20,5))
sns.heatmap(corr, annot=True, ax =ax)
plt.savefig('heatmapEX1.png')

# %% [markdown]
# #### 5) Quel est le top 3 des features qu’on devrait garder pour prédire notre prix ?
