# %% [markdown]
# # Data Visualisation Statistiques descriptives

# %% [markdown]
# ## Visualisation d’un nuage de points et exploration des variables

# %% [markdown]
# #### 1.Importez les librairies qu’il nous faut (pandas, seaborn, matplotlib, numpy)

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt 
import seaborn as sns

# %% [markdown]
# #### 2.Donnez la liste des variables présentes dans ce dataset ainsi que leur nature (sont elles qualitatives, quantitatives, discrète etc...) et leur type (float, int, str etc...)

# %%
df = pd.read_csv('./data/house_pricing.csv')
df
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0        1          60       RL         65.0     8450   Pave   NaN      Reg
# 1        2          20       RL         80.0     9600   Pave   NaN      Reg
# 2        3          60       RL         68.0    11250   Pave   NaN      IR1
# 3        4          70       RL         60.0     9550   Pave   NaN      IR1
# 4        5          60       RL         84.0    14260   Pave   NaN      IR1
# ...    ...         ...      ...          ...      ...    ...   ...      ...
# 1455  1456          60       RL         62.0     7917   Pave   NaN      Reg
# 1456  1457          20       RL         85.0    13175   Pave   NaN      Reg
# 1457  1458          70       RL         66.0     9042   Pave   NaN      Reg
# 1458  1459          20       RL         68.0     9717   Pave   NaN      Reg
# 1459  1460          20       RL         75.0     9937   Pave   NaN      Reg
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1460 entries, 0 to 1459
# Data columns (total 81 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             1460 non-null   int64
#  1   MSSubClass     1460 non-null   int64
#  2   MSZoning       1460 non-null   object
#  3   LotFrontage    1201 non-null   float64
#  4   LotArea        1460 non-null   int64
#  5   Street         1460 non-null   object
#  6   Alley          91 non-null     object
#  7   LotShape       1460 non-null   object
#  8   LandContour    1460 non-null   object
#  9   Utilities      1460 non-null   object
#  10  LotConfig      1460 non-null   object
#  11  LandSlope      1460 non-null   object
#  12  Neighborhood   1460 non-null   object
#  13  Condition1     1460 non-null   object
#  14  Condition2     1460 non-null   object
#  15  BldgType       1460 non-null   object
#  16  HouseStyle     1460 non-null   object
# ...

# %% [markdown]
# #### 3.En créant un nuage de points, regardez comment se comporte la colonne LotArea par rapport au SalesPrices

# %%
sns.regplot(x="LotArea", y="SalePrice" , data= df , fit_reg=False)
# Out:
# <AxesSubplot:xlabel='LotArea', ylabel='SalePrice'>

# %% [markdown]
# #### 4.Affinez votre visualisation en ne gardant uniquement les maisons qui ont un LotArea inférieur à 20 000 pieds carrés et un prix inférieur à 500 000

# %%
sns.regplot(x="LotArea", y="SalePrice" , data= df , fit_reg=False)
plt.ylim(0,50000)
plt.xlim(0,20000)
# Out:
# (0.0, 20000.0)

# %% [markdown]
# ### correction

# %%
hp_data = pd.read_csv('./data/house_pricing.csv')
toto = hp_data[hp_data < 20000]
toto = toto[toto["SalePRice"] < 500000]
sns.scatterplot(data=toto , x="LotArea", y="SalePrice")
# Out:
# <AxesSubplot:xlabel='LotArea', ylabel='SalePrice'>

# %%
hp_data = pd.read_csv('./data/house_pricing.csv')
sns.scatterplot(data=hp_data[(hp_data["LotArea"] < 20000)&(hp_data["SalePrice"] < 500000)] , x="LotArea", y="SalePrice")
# Out:
# <AxesSubplot:xlabel='LotArea', ylabel='SalePrice'>

# %% [markdown]
# #### 5.En créant un nuage de points, regardez la relation entre le LotFrontage et le LotArea

# %%
sns.regplot(x="LotFrontage", y="LotArea" , data=df , fit_reg=False)
# Out:
# <AxesSubplot:xlabel='LotFrontage', ylabel='LotArea'>

# %% [markdown]
# #### 6.De la même manière, affinez votre visualisation en ne gardant uniquement les maisons qui ont un LotFrontage inférieur à 200 pieds carrés et un LotArea inférieur à 100000 pieds carré

# %%
df = pd.read_csv('./data/house_pricing.csv')
sns.regplot(x="LotFrontage", y="LotArea" , data=df , fit_reg=False)
plt.ylim(0,100000)
plt.xlim(0,200)
# Out:
# (0.0, 200.0)

# %% [markdown]
# correction

# %%
hp_data = pd.read_csv('./data/house_pricing.csv')
sns.scatterplot(data=hp_data[(hp_data["LotArea"] < 100000)&(hp_data["LotFrontage"] < 200)] , x="LotFrontage", y="LotArea")
# Out:
# <AxesSubplot:xlabel='LotFrontage', ylabel='LotArea'>

# %% [markdown]
# ## Visualisation de relations continues

# %% [markdown]
# #### 1) Importez les librairies qu’il vous faut

# %%
pred = pd.read_csv('./data/sales_predictions.csv')
pred
# Out:
#                date  date_block_num  shop_id  item_id  item_price  \
# 0        02.01.2013               0       59    22154      999.00
# 1        03.01.2013               0       25     2552      899.00
# 2        05.01.2013               0       25     2552      899.00
# 3        06.01.2013               0       25     2554     1709.05
# 4        15.01.2013               0       25     2555     1099.00
# ...             ...             ...      ...      ...         ...
# 2935844  10.10.2015              33       25     7409      299.00
# 2935845  09.10.2015              33       25     7460      299.00
# 2935846  14.10.2015              33       25     7459      349.00
# 2935847  22.10.2015              33       25     7440      299.00
# 2935848  03.10.2015              33       25     7460      299.00
#
#          item_cnt_day
# 0                 1.0
# 1                 1.0
# 2                -1.0
# 3                 1.0
# 4                 1.0
# ...               ...
# ...

# %%
pred.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2935849 entries, 0 to 2935848
# Data columns (total 6 columns):
#  #   Column          Dtype
# ---  ------          -----
#  0   date            object
#  1   date_block_num  int64
#  2   shop_id         int64
#  3   item_id         int64
#  4   item_price      float64
#  5   item_cnt_day    float64
# dtypes: float64(2), int64(3), object(1)
# memory usage: 134.4+ MB

# %% [markdown]
# #### 2) En utilisant relplot(), construisez un graphique qui va vous permettre de voir l’évolutiondes prix par rapport au temps. Que pouvez vous voir ?

# %%
g = sns.relplot(data=pred , x="date",y="item_price")

# %% [markdown]
# #### 3) Corrigeons le problème de visualisation, en utilisant la fonction .sample() de Pandas, prenez un échantillons de 50 éléments dans votre dataset

# %%
g = sns.relplot(data=pred.sample(50) , x="date",y="item_price")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-53-7ce89d748bef> in <module>
# ----> 1 g.sample(x=50)
#
# AttributeError: 'FacetGrid' object has no attribute 'sample'
